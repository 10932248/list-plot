# %% [markdown]
# <a href="https://colab.research.google.com/github/10932248/list-plot/blob/main/list_plot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

# %%
x=[1,2,3,4,5,6]

# %%
plt.plot(x)

# %%
y=[i*i for i in x]

# %%
y
# Out:
# [1, 4, 9, 16, 25, 36]

# %%
plt.plot(y)

# %%
yy=[]
for z in x:
  yy.append(z*z)

# %%
yy
# Out:
# [1, 4, 9, 16, 25, 36]
